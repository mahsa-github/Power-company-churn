# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# %%
client_df = pd.read_csv(r'D:\2024\data science portfolio\data\BCG\PowerCO/client_data.csv')
price_df = pd.read_csv(r'D:\2024\data science portfolio\data\BCG\PowerCO/price_data.csv')

# %% [markdown]
# Data Overview

# %%
client_df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %% [markdown]
# General Observations
# •  Count: Each column has 14,606 entries, indicating no missing values in the dataset.
#
# •  Mean and Standard Deviation: The mean and standard deviation values provide an overview of the central tendency and dispersion of the data.
#
#  - first column : There is a wide range of consumption values, with some customers having zero consumption and others having very high consumption.
#  - Gas consumption : Similar to electricity consumption, gas consumption also varies widely.
#  - The average customer has been with the company for about 5 years, with some customers having a long tenure of up to 13 years.
#  - we have highly skewed data, as exhibited by the percentile values.
#
# *Key Takeaways
# •  There is significant variability in consumption, both for electricity and gas, indicating diverse customer usage patterns.
#
# •  The forecasted consumption is generally lower than actual consumption, which might suggest conservative forecasting or potential underestimation.
#
# •  Margins (both gross and net) vary widely, indicating different levels of profitability across customers.
#
# •  The churn rate is relatively low at around 9.7%, but understanding the factors influencing this churn is crucial for improving customer retention.

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# - The variable off-peak price has a relatively low mean and standard deviation, indicating that most values are close to the mean.
# - The fixed off-peak price has a higher mean and standard deviation, indicating a wider range of fixed prices.
# - The variability in pricing, especially during peak periods, could influence customer decisions and potentially impact churn rates.

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# Data Visualization

# %% [markdown]
# Objective: To understand the distribution of electricity consumption among clients.
#
# Rationale: This helps identify patterns in consumption, such as whether most clients consume a similar amount of electricity or if there are significant outliers.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(client_df['cons_12m'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Electricity Consumption in 12 Months')
plt.xlabel('Consumption (kWh)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2. Churn Rate by Number of Products (Bar Plot)
#
# Objective: To compare churn rates across different numbers of products a customer has.
# Rationale: This helps identify if customers with more products are less likely to churn.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='nb_prod_act', y='churn', data=client_df, palette='Greens')
plt.title('Churn Rate by Number of Products')
plt.xlabel('Number of Products')
plt.ylabel('Churn Rate')
plt.show()
# Out:
# C:\Users\Mahsa\AppData\Local\Temp\ipykernel_6668\2963898695.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='nb_prod_act', y='churn', data=client_df, palette='Greens')

# %% [markdown]
# 3- Price Sensitivity Analysis (Scatter Plot with Regression Line)
#
# Objective: To visualize the relationship between peak variable price and electricity consumption.
#
# Rationale: This helps determine if higher peak prices correlate with higher or lower consumption.

# %%
merged_df = pd.merge(price_df, client_df, on='id')


plt.figure(figsize=(10, 6))
sns.regplot(x=merged_df['price_peak_var'], y=merged_df['cons_12m'], scatter_kws={'color':'orange'}, line_kws={'color':'red'})
plt.title('Price Sensitivity Analysis')
plt.xlabel('Peak Variable Price')
plt.ylabel('Consumption (kWh)')
plt.show()

# %% [markdown]
# 4. Correlation Heatmap
# Objective: To identify correlations between different pricing variables and consumption.
#
# Rationale: This helps in understanding which pricing factors are most strongly associated with consumption.
#
# Color Scheme: Use a cool-to-warm gradient (blue to red) to easily distinguish positive and negative correlations.

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = merged_df[['price_off_peak_var', 'price_peak_var', 'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix', 'cons_12m']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
